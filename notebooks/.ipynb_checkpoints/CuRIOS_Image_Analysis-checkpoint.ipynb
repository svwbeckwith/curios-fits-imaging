# %% [markdown]
# # CuRIOS FITS Imaging - Version 2.8
#
# This notebook demonstrates the standard workflow for analyzing a CuRIOS FITS image.
#
# Workflow:
#
# 1. Configure analysis parameters
# 2. Select an observing folder and image
# 3. Analyze the image
# 4. Display the standard report
# 5. (Optional) Run additional diagnostics
#
# For advanced examples, see the notebooks in the `examples/` directory.

# %%
import matplotlib.pyplot as plt
import numpy as np

from fits_imaging.config import ImagingConfig
from fits_imaging.session import ImagingSession

# %%
config = ImagingConfig()

# Optional display choices
config.colormap = "viridis"
config.contrast_method = "sigma"
config.contrast_sigma_low = 1.0
config.contrast_sigma_high = 5.0
config.stretch = "linear"

config
# Out:
# ImagingConfig(data_root=PosixPath('/Users/svwbeckwith/Dropbox/CuRIOS/Software/DataDirectories'), zero_mag_counts=115000000, pixel_arcsec=1.24, threshold_sigma=5.0, max_peaks=1000, peak_separation=10.0, peak_sharp=0.2, fit_method='gaussian', contrast_method='sigma', contrast_percentiles=(1.0, 99.8), contrast_sigma_low=1.0, contrast_sigma_high=5.0, stretch='linear', colormap='viridis', invert_colormap=False, invert_gray=False, histogram_max_points=2000000, histogram_bins=200, stats_region='center_fraction', stats_center_fraction=0.5, stats_center_pixels=2000, source_region='center_fraction', source_region_fraction=0.5)

# %%
session = ImagingSession()
session.status()
# Out:
# Data root:      /Users/svwbeckwith/Dropbox/CuRIOS/Software/DataDirectories
# Current folder: /Users/svwbeckwith/Dropbox/CuRIOS/Software/DataDirectories/Patio-0629
# Last image:     /Users/svwbeckwith/Dropbox/CuRIOS/Software/DataDirectories/Patio-0629/Neptune_2026-06-29_10.40.37_CuED-0.fits

# %%
results = session.analyze(config)
#results
# Out:
# File#       File
# ----------------------------------------------------------------------
#     0       Altair-Bahtinov_2026-06-29_08.15.59_CuED-0.fits
#     1       Altair-Bahtinov_2026-06-29_08.15.59_CuED_0_sum.fits
#     2       Altair-Bahtinov_2026-06-29_08.21.48_CuED-0.fits
#     3       Altair-Bahtinov_2026-06-29_08.26.49_CuED-0.fits
#     4       M15_2026-06-29_10.20.58_CuED_10_sum.fits
#     5       M57_2026-06-29_10.06.46_CuED_5_sum.fits
#     6       M71_2026-06-29_10.11.32_CuED_10_sum.fits
#     7       Neptune_2026-06-29_10.30.12_CuED-0.fits
#     8       Neptune_2026-06-29_10.30.12_CuED_4_sum.fits
#     9       Neptune_2026-06-29_10.40.37_CuED-0.fits
#    10       Neptune_2026-06-29_10.40.37_CuED_4_sum.fits
#    11       Polaris_2026-06-29_08.56.03_CuED_5_sum.fits
#    12       Polaris_2026-06-29_08.59.05_CuED-0.fits
#    13       Saturn_2026-06-29_10.45.04_CuED-0.fits
#    14       Saturn_2026-06-29_10.45.04_CuED_9_sum.fits
#    15       Vega-Bahtinov_2026-06-29_09.26.41_CuED-0.fits
#    16       VegaBC_2026-06-29_10.55.26_CuED-0.fits
#    17       VegaBL2_2026-06-29_11.00.28_CuED-0.fits
#    18       VegaBL_2026-06-29_10.56.03_CuED-0.fits
#    19       VegaBR2_2026-06-29_10.59.48_CuED-0.fits
#    20       VegaBR_2026-06-29_10.56.41_CuED-0.fits
#    21       VegaC0_2026-06-29_09.28.16_CuED-0.fits
#    22       VegaC0_2026-06-29_09.32.52_CuED-0.fits
#    23       VegaC0_2026-06-29_09.40.55_CuED-0.fits
#    24       VegaC0_2026-06-29_09.54.49_CuED-0.fits
#    25       VegaC0_2026-06-29_10.02.49_CuED-0.fits
#    26       VegaC0_2026-06-29_10.52.55_CuED-0.fits
#    27       VegaC0_2026-06-29_11.01.04_CuED-0.fits
#    28       VegaCL_2026-06-29_10.53.33_CuED-0.fits
#    29       VegaCR_2026-06-29_10.54.11_CuED-0.fits
#    30       VegaD1_2026-06-29_09.35.17_CuED-0.fits
#    31       VegaD1_2026-06-29_09.57.16_CuED-0.fits
#    32       VegaD2_2026-06-29_09.35.55_CuED-0.fits
#    33       VegaD2_2026-06-29_09.57.52_CuED-0.fits
#    34       VegaD3_2026-06-29_09.36.31_CuED-0.fits
#    35       VegaD3_2026-06-29_09.58.30_CuED-0.fits
#    36       VegaL1_2026-06-29_09.39.02_CuED-0.fits
#    37       VegaL2_2026-06-29_09.39.39_CuED-0.fits
#    38       VegaL2_2026-06-29_10.01.33_CuED-0.fits
#    39       VegaL3_2026-06-29_09.40.17_CuED-0.fits
#    40       VegaL3_2026-06-29_10.02.10_CuED-0.fits
#    41       VegaR1_2026-06-29_09.37.08_CuED-0.fits
#    42       VegaR1_2026-06-29_09.59.06_CuED-0.fits
#    43       VegaR2_2026-06-29_09.37.45_CuED-0.fits
#    44       VegaR2_2026-06-29_09.59.44_CuED-0.fits
#    45       VegaR3_2026-06-29_09.38.22_CuED-0.fits
#    46       VegaR3_2026-06-29_10.00.20_CuED-0.fits
#    47       VegaTC_2026-06-29_10.54.48_CuED-0.fits
#    48       VegaTL2_2026-06-29_10.58.33_CuED-0.fits
#    49       VegaTL_2026-06-29_10.57.56_CuED-0.fits
#    50       VegaTR2_2026-06-29_10.59.11_CuED-0.fits
#    51       VegaTR_2026-06-29_10.57.18_CuED-0.fits
#    52       VegaU1_2026-06-29_09.28.52_CuED-0.fits
#    53       VegaU1_2026-06-29_09.33.28_CuED-0.fits
#    54       VegaU1_2026-06-29_09.55.25_CuED-0.fits
#    55       VegaU2_2026-06-29_09.29.30_CuED-0.fits
#    56       VegaU2_2026-06-29_09.34.04_CuED-0.fits
#    57       VegaU2_2026-06-29_09.56.02_CuED-0.fits
#    58       VegaU3_2026-06-29_09.30.06_CuED-0.fits
#    59       VegaU3_2026-06-29_09.34.40_CuED-0.fits
#    60       VegaU3_2026-06-29_09.56.40_CuED-0.fits
#    61       Vega_2026-06-29_09.10.59_CuED_5_sum.fits
#    62       Vega_2026-06-29_09.14.39_CuED-0.fits
# ----------------------------------------------------------------------
# Enter file number to analyze:  11

# %%
results.report(
    config=config,
    show_summary=True,
    show_image=True,
    show_table=True,
    show_cutouts=True,
    show_histogram=False,
    show_statistics=True,
)
# Out:
# Polaris  9576 x 6380  Apx60-CuED  0.050 sec
# RAH:   0.000  Dec:   0.000  PA: 360.00  PA2:   0.00  Alt:     0.0  Az:     0.0
# Mean: 493.4  Median: 493.0  Std: 11.0  Min: 44.0  Max: 9214.0
# Found 124 peaks in 2.88 sec
#
# Source statistics:
# {'nstars': 124, 'median_fwhm': 1.5893886089324951, 'median_flux': 254.0, 'brightest_flux': 251476.0}
#
# Selected-region source statistics:
# {'nstars': 36, 'median_fwhm': 1.5544309616088867, 'median_flux': 238.5, 'brightest_flux': 251476.0}
# Peak#        X        Y        Area       sx      sy        Flux      Mag
# ------------------------------------------------------------------------------
#     0   4776.72   3226.19    301877.5    2.97    3.04    251476.0    3.398
#     1   5447.82   2858.97      6794.6    4.44    3.32      4005.0    7.893
#     2   2921.45   5950.41       858.7    0.72    0.54      1037.0    9.360
#     3   1440.20   1972.56       322.6    0.66    0.65       637.0    9.889
#     4   5995.45     93.47       609.4    0.72    0.53       633.0    9.896
#     5   5920.53   6125.36       564.6    0.73    0.56       631.0    9.899
#     6   3728.40   4493.10       307.7    0.79    0.63       605.0    9.945
#     7    635.45   4203.18       369.9    0.81    0.75       565.0   10.019
#     8   5637.54   4921.14       536.7    0.39    0.65       555.0   10.038
#     9   4869.15   4228.69       392.3    0.80    0.72       484.0   10.187
#    10   7394.72     41.10       338.8    0.48    0.91       474.0   10.210
#    11   3354.26   1196.66       290.6    0.75    0.65       473.0   10.212
#    12   9422.32   4560.99       330.1    0.76    0.79       472.0   10.214
#    13   2617.47   3910.51       359.7    0.56    0.70       440.0   10.291
#    14    659.72   4529.25       353.9    0.71    0.77       438.0   10.295
#    15   5584.59   1494.79       290.1    0.81    0.56       435.0   10.303
#    16    796.03   2600.88       335.2    0.67    0.90       430.0   10.315
#    17   7211.15   4075.18       505.2    1.22    0.88       411.0   10.365
#    18   4951.29   2978.65       419.0    0.70    0.65       410.0   10.367
#    19   6736.38   4868.42       336.6    0.78    0.54       391.0   10.419
#    20   6658.56   5811.67       396.6    0.98    0.77       391.0   10.419
#    21   6148.44   5168.84       327.9    0.46    0.70       389.0   10.424
#    22   3406.50   6268.27       260.3    0.51    0.66       380.0   10.450
#    23   4638.52   4058.87       353.2    0.61    0.79       378.0   10.455
#    24   3264.19   2516.98       390.2    0.51    0.98       376.0   10.461
#    25   1529.82   3674.97       270.5    0.86    0.57       376.0   10.461
#    26   3769.30   2530.98       265.7    0.65    0.69       372.0   10.473
#    27   7790.71   5264.46       351.7    0.53    0.36       371.0   10.476
#    28   4499.54   5171.07       261.2    0.56    0.66       363.0   10.499
#    29   8081.32   4668.47       423.7    0.70    0.56       359.0   10.511
#    30   6581.62   2818.77       446.4    0.54    0.83       356.0   10.521
#    31   3131.82    399.04       342.0    0.59    0.87       356.0   10.521
#    32   1588.79    170.07       310.6    0.61    0.81       353.0   10.530
#    33   1679.10   4046.57       305.5    0.75    0.64       349.0   10.542
#    34   1415.38   6320.31       231.5    0.50    0.63       348.0   10.545
#    35   7340.35   2974.69       406.3    0.76    0.41       345.0   10.555
#    36   6957.58   2901.14       306.7    0.59    0.68       343.0   10.561
#    37   4393.46   5522.31       351.5    0.78    0.60       342.0   10.564
#    38   5413.65   4416.73       448.9    0.55    1.06       341.0   10.567
#    39   7862.93   4858.99       274.8    0.83    0.58       326.0   10.616
#    40   2266.85   2055.02       348.2    0.55    0.98       326.0   10.616
#    41   6263.94   2966.73       345.3    0.87    0.54       321.0   10.633
#    42    213.16   4040.09       330.3    0.63    0.96       320.0   10.636
#    43   9359.12   4074.60       283.0    0.60    0.64       317.0   10.647
#    44   8486.04   2582.42       456.9    0.74    1.01       313.0   10.660
#    45   6729.48   2405.03       302.0    0.51    0.69       308.0   10.678
#    46   4449.48    326.41       402.7    0.76    0.53       307.0   10.681
#    47   8838.08   1078.77       370.7    0.62    0.82       302.0   10.699
#    48   5209.99   5429.09       319.6    0.75    0.72       301.0   10.703
#    49   4709.40   5402.85       356.7    0.71    0.83       300.0   10.706

# %%
results.plot_histogram(config=config)
plt.show()

# %%
results.source_statistics()
# Out:
# {'nstars': 124,
#  'median_fwhm': 1.5893886089324951,
#  'median_flux': 254.0,
#  'brightest_flux': 251476.0}

# %%
results.selected_source_statistics(config=config)
# Out:
# {'nstars': 36,
#  'median_fwhm': 1.5544309616088867,
#  'median_flux': 238.5,
#  'brightest_flux': 251476.0}

# %%
results.plot_psf_profile()
results.plot_encircled_energy()
results.plot_fwhm_histogram()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 results.plot_psf_profile()
#       2 results.plot_encircled_energy()
#       3 results.plot_fwhm_histogram()
#
# AttributeError: 'ImagingResults' object has no attribute 'plot_psf_profile'
