# %% [markdown]
# # CuRIOS FITS Imaging - Version 2.9
#
# This notebook demonstrates the standard workflow for analyzing a CuRIOS FITS image.
#
# Workflow:
#
# 1. Configure analysis parameters
# 2. Select an observing folder and image
# 3. Analyze the image
# 4. Display the standard report
# 5. (Optional) Run additional diagnostics
#
# For advanced examples, see the notebooks in the `examples/` directory.

# %%
import os
import sys
from pathlib import Path

cwd = Path.cwd()

if cwd.name == "notebooks":
    project_root = cwd.parent
else:
    project_root = cwd

sys.path.insert(0, str(project_root))

from fits_imaging.config import ImagingConfig
from fits_imaging.analysis import analyze_image
from fits_imaging.session import ImagingSession

# %%
data_root_text = os.environ.get(
    "CURIOS_DATA_ROOT",
    "~/Dropbox/CuRIOS/DataDirectories",
)

data_root = Path(data_root_text).expanduser().resolve()

if not data_root.exists():
    raise FileNotFoundError(
        f"Data directory does not exist: {data_root}. "
        "Set the CURIOS_DATA_ROOT environment variable or edit data_root."
    )

config = ImagingConfig(data_root=data_root)

config.colormap = "viridis"
config.contrast_method = "sigma"
config.contrast_sigma_low = 1.0
config.contrast_sigma_high = 5.0
config.stretch = "linear"

session = ImagingSession(data_root=data_root)

print("Data root:", session.data_root)
print("State file:", session.state_path)
print("Configuration updated")
# Out:
# Data root: /Users/svwbeckwith/Dropbox/CuRIOS/DataDirectories
# State file: /Users/svwbeckwith/.config/curios-fits-imaging/session.json
# Configuration updated

# %%
session.folder_table()
# Out:
#    index      folder                                               path
# 0      0     Archive  /Users/svwbeckwith/Dropbox/CuRIOS/DataDirector...
# 1      1    CowTests  /Users/svwbeckwith/Dropbox/CuRIOS/DataDirector...
# 2      2      Images  /Users/svwbeckwith/Dropbox/CuRIOS/DataDirector...
# 3      3    Lib-0610  /Users/svwbeckwith/Dropbox/CuRIOS/DataDirector...
# 4      4  Patio-0629  /Users/svwbeckwith/Dropbox/CuRIOS/DataDirector...
# 5      5  Patio-0703  /Users/svwbeckwith/Dropbox/CuRIOS/DataDirector...
# 6      6  Patio-0720  /Users/svwbeckwith/Dropbox/CuRIOS/DataDirector...
# 7      7  Patio-0725  /Users/svwbeckwith/Dropbox/CuRIOS/DataDirector...
# 8      8  Patio-0726  /Users/svwbeckwith/Dropbox/CuRIOS/DataDirector...

# %%
folder_index = 8
selected_folder = session.set_folder_by_index(folder_index)

print("Selected folder:", selected_folder)
# Out:
# Selected folder: /Users/svwbeckwith/Dropbox/CuRIOS/DataDirectories/Patio-0726

# %%
run = session.open_run()

print("FITS files:", len(run.files))
print("Image types:", run.kinds())
run.preview(kind="science", n=25)
# Out:
# FITS files: 9
# Image types: ['science_single', 'science_sum']
#    index                                          file            kind  \
# 0      0        Alkaid_2026-07-27_04.00.51_CuED-0.fits  science_single
# 1      1    Altair_2026-07-27_04.11.14_CuED_5_sum.fits     science_sum
# 2      2   Antares_2026-07-27_04.05.13_CuED_5_sum.fits     science_sum
# 3      3  Arcturus_2026-07-27_04.02.03_CuED_5_sum.fits     science_sum
# 4      4     Deneb_2026-07-27_04.13.59_CuED_5_sum.fits     science_sum
# 5      5         Dubhe_2026-07-27_03.56.42_CuED-0.fits  science_single
# 6      6   Polaris_2026-07-27_03.52.41_CuED_5_sum.fits     science_sum
# 7      7     Spica_2026-07-27_03.58.00_CuED_5_sum.fits     science_sum
# 8      8      Vega_2026-07-27_04.08.06_CuED_5_sum.fits     science_sum
#
#    frame_count total_exposure_sec  include
# 0            1               None     True
# 1            5               None     True
# 2            5               None     True
# 3            5               None     True
# 4            5               None     True
# 5            1               None     True
# 6            5               None     True
# 7            5               None     True
# 8            5               None     True

# %%
image_index = 4

threshold_sigma = 10.0
max_peaks = 100

config.threshold_sigma = threshold_sigma
config.max_peaks = max_peaks

image_path = session.set_image_by_index(image_index, kind="science")
results = analyze_image(image_path, config)

print("Selected image:", image_path)
print("Analysis complete")
# Out:
# Selected image: /Users/svwbeckwith/Dropbox/CuRIOS/DataDirectories/Patio-0726/Deneb_2026-07-27_04.13.59_CuED_5_sum.fits
# Analysis complete

# %%
results.report(
    config=config,
    show_summary=True,
    show_image=True,
    show_table=True,
    show_cutouts=True,
    show_histogram=False,
    show_statistics=True,
)
# Out:
# Deneb  9576 x 6380  Apx60-CuED  0.125 sec
# Analysis mode: source_detection
# Exposure: 0.025 sec x 5 frame(s) = 0.125 sec total; photometry uses 0.125 sec
# RAH:  20.691  Dec:  45.280  PA: 284.81  PA2:  75.19  Alt:    42.5  Az:    59.4
# Mean: 493.6  Median: 494.0  Std: 11.6  Min: 99.0  Max: 9570.0
# Found 30 peaks in 2.82 sec
#
# Source statistics:
# {'nstars': 30, 'median_fwhm': 1.5717251300811768, 'median_flux': 286.5, 'brightest_flux': 300033.0}
#
# Selected-region source statistics:
# {'nstars': 10, 'median_fwhm': 1.5778746604919434, 'median_flux': 262.0, 'brightest_flux': 300033.0}
# Peak#        X        Y        Area       sx      sy        Flux      Mag
# ------------------------------------------------------------------------------
#     0   4389.88   4291.56    380932.9    3.05    3.25    300033.0    4.201
#     1   2033.68    482.05      9179.7    5.23    3.97      4145.0    8.850
#     2   1808.37   4505.59      5063.7    1.83    4.60      2593.0    9.360
#     3   4472.58   5091.22       294.1    0.78    0.72       605.0   10.940
#     4   3404.52   2209.36      4668.6    0.24    1.77       533.0   11.077
#     5   4242.95   1487.48       261.8    0.59    0.70       494.0   11.160
#     6   3125.73    921.51       288.6    0.56    0.66       484.0   11.182
#     7   6950.33   4403.25       302.6    0.74    0.47       469.0   11.216
#     8   3158.94   2723.57       473.2    0.64    1.21       468.0   11.218
#     9   5022.94   5153.59       286.1    0.66    0.75       411.0   11.359
#    10   4643.69   6355.16       308.4    0.48    0.86       411.0   11.359
#    11    497.85    177.29       292.8    0.53    0.85       391.0   11.414
#    12   8759.90   5991.77       270.5    0.58    0.80       386.0   11.428
#    13   2381.14   5805.67       276.8    0.50    0.83       315.0   11.648
#    14   1249.69    459.39       242.7    0.49    0.65       296.0   11.716
#    15   8643.78   5655.58       346.1    0.65    0.73       277.0   11.788
#    16   1868.77   3561.46       300.1    0.59    0.68       275.0   11.796
#    17   7135.74   4345.29       340.0    0.49    0.84       263.0   11.844
#    18   6202.58   4087.82      1202.0    0.22    0.75       261.0   11.852
#    19   1641.78   3643.62       301.4    0.69    0.77       256.0   11.873
#    20   7127.09   3449.28       243.8    0.50    0.78       247.0   11.912
#    21   2818.79   4317.05       241.2    0.63    0.72       244.0   11.926
#    22   5448.09   1667.89       341.0    0.35    1.05       235.0   11.966
#    23   6381.91   5097.67       267.2    0.58    0.68       110.0   12.791
#    24   1615.83    475.37       293.7    0.47    0.88       107.0   12.821
#    25   3005.67   3803.54       274.3    0.46    0.74        88.0   13.033
#    26   1895.76   2693.94       215.3    0.67    0.65        68.0   13.313
#    27   6425.88   1027.54       290.4    0.65    0.59        41.0   13.862
#    28   8835.90   3085.67       277.5    0.56    0.67        13.0   15.109
#    29   1578.74   2677.52       662.7    0.64    0.27      -133.0   12.584

# %%
import matplotlib.pyplot as plt
results.plot_histogram(config=config, bins=50)
plt.show()

# %%
results.source_statistics()
# Out:
# {'nstars': 30,
#  'median_fwhm': 1.5717251300811768,
#  'median_flux': 286.5,
#  'brightest_flux': 300033.0}

# %%
batch_results, batch_summary = session.analyze_current_folder(
    config,
    kind="science",
    max_files=10,
)

batch_summary
# Out:
# [1/9] Alkaid_2026-07-27_04.00.51_CuED-0.fits
# [2/9] Altair_2026-07-27_04.11.14_CuED_5_sum.fits
# [3/9] Antares_2026-07-27_04.05.13_CuED_5_sum.fits
# [4/9] Arcturus_2026-07-27_04.02.03_CuED_5_sum.fits
# [5/9] Deneb_2026-07-27_04.13.59_CuED_5_sum.fits
# [6/9] Dubhe_2026-07-27_03.56.42_CuED-0.fits
# [7/9] Polaris_2026-07-27_03.52.41_CuED_5_sum.fits
# [8/9] Spica_2026-07-27_03.58.00_CuED_5_sum.fits
# [9/9] Vega_2026-07-27_04.08.06_CuED_5_sum.fits
#                                            file  \
# 0        Alkaid_2026-07-27_04.00.51_CuED-0.fits
# 1    Altair_2026-07-27_04.11.14_CuED_5_sum.fits
# 2   Antares_2026-07-27_04.05.13_CuED_5_sum.fits
# 3  Arcturus_2026-07-27_04.02.03_CuED_5_sum.fits
# 4     Deneb_2026-07-27_04.13.59_CuED_5_sum.fits
# 5         Dubhe_2026-07-27_03.56.42_CuED-0.fits
# 6   Polaris_2026-07-27_03.52.41_CuED_5_sum.fits
# 7     Spica_2026-07-27_03.58.00_CuED_5_sum.fits
# 8      Vega_2026-07-27_04.08.06_CuED_5_sum.fits
#
#                                                 path            kind  \
# 0  /Users/svwbeckwith/Library/CloudStorage/Dropbo...  science_single
# 1  /Users/svwbeckwith/Library/CloudStorage/Dropbo...     science_sum
# 2  /Users/svwbeckwith/Library/CloudStorage/Dropbo...     science_sum
# 3  /Users/svwbeckwith/Library/CloudStorage/Dropbo...     science_sum
# 4  /Users/svwbeckwith/Library/CloudStorage/Dropbo...     science_sum
# 5  /Users/svwbeckwith/Library/CloudStorage/Dropbo...  science_single
# 6  /Users/svwbeckwith/Library/CloudStorage/Dropbo...     science_sum
# 7  /Users/svwbeckwith/Library/CloudStorage/Dropbo...     science_sum
# 8  /Users/svwbeckwith/Library/CloudStorage/Dropbo...     science_sum
#
#       analysis_mode    object      camera  exposure_sec  frame_count  \
# 0  source_detection    Alkaid  Apx60-CuED         0.010            1
# 1  source_detection    Altair  Apx60-CuED         0.015            5
# 2  source_detection   Antares  Apx60-CuED         0.020            5
# 3  source_detection  Arcturus  Apx60-CuED         0.005            5
# 4  source_detection     Deneb  Apx60-CuED         0.025            5
# 5  source_detection     Dubhe  Apx60-CuED         0.009            1
# 6  source_detection   Polaris  Apx60-CuED         0.060            5
# 7  source_detection     Spica  Apx60-CuED         0.020            5
# 8  source_detection      Vega  Apx60-CuED         0.005            5
#
#    total_exposure_sec  photometry_exposure_sec  ... nstars  \
# 0               0.010                    0.010  ...      2
# 1               0.075                    0.075  ...      2
# 2               0.100                    0.100  ...      5
# 3               0.025                    0.025  ...      8
# 4               0.125                    0.125  ...     30
# 5               0.009                    0.009  ...      1
# 6               0.300                    0.300  ...      1
# 7               0.100                    0.100  ...      3
# 8               0.025                    0.025  ...     19
#
#    median_fwhm_pixels  median_background  background_sigma  brightest_flux  \
# 0            7.343746              108.0          5.866696         45431.0
# 1            3.950277              494.0         17.276219        240230.0
# 2            8.870814              503.0         20.413080        170222.0
# 3            1.682539              494.0         16.866729        184624.0
# 4            1.571725              494.0         11.645672        300033.0
# 5           10.622739              140.0          9.749600         36481.0
# 6           11.397878              862.0         47.913969        216455.0
# 7            9.528467              538.0         22.084392        321807.0
# 8            1.434802              492.0         11.982880        199344.0
#
#    peak_find_time_sec     stats_region focus_sharpness gradient_anisotropy  \
# 0            3.866391  center_fraction            None                None
# 1            3.948995  center_fraction            None                None
# 2            3.934131  center_fraction            None                None
# 3            3.892241  center_fraction            None                None
# 4            3.951687  center_fraction            None                None
# 5            3.914415  center_fraction            None                None
# 6            3.872975  center_fraction            None                None
# 7            4.067265  center_fraction            None                None
# 8            3.948181  center_fraction            None                None
#
#   gradient_angle_deg
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None
# 5               None
# 6               None
# 7               None
# 8               None
#
# [9 rows x 21 columns]

# %%
batch_summary.to_csv("batch_summary.csv", index=False)

# %%
run = session.open_run()

len(run.files), run.folder, run.kinds()
# Out:
# (9,
#  PosixPath('/Users/svwbeckwith/Library/CloudStorage/Dropbox/CuRIOS/Software/DataDirectories/Patio-0726'),
#  ['science_single', 'science_sum'])

# %%
run.file_table[["file", "kind", "include"]]
# Out:
#                                            file            kind  include
# 0        Alkaid_2026-07-27_04.00.51_CuED-0.fits  science_single     True
# 1    Altair_2026-07-27_04.11.14_CuED_5_sum.fits     science_sum     True
# 2   Antares_2026-07-27_04.05.13_CuED_5_sum.fits     science_sum     True
# 3  Arcturus_2026-07-27_04.02.03_CuED_5_sum.fits     science_sum     True
# 4     Deneb_2026-07-27_04.13.59_CuED_5_sum.fits     science_sum     True
# 5         Dubhe_2026-07-27_03.56.42_CuED-0.fits  science_single     True
# 6   Polaris_2026-07-27_03.52.41_CuED_5_sum.fits     science_sum     True
# 7     Spica_2026-07-27_03.58.00_CuED_5_sum.fits     science_sum     True
# 8      Vega_2026-07-27_04.08.06_CuED_5_sum.fits     science_sum     True

# %%
summary = run.analyze_all(config, kind="science", max_files=5)
summary
# Out:
# [1/5] Alkaid_2026-07-27_04.00.51_CuED-0.fits
# [2/5] Altair_2026-07-27_04.11.14_CuED_5_sum.fits
# [3/5] Antares_2026-07-27_04.05.13_CuED_5_sum.fits
# [4/5] Arcturus_2026-07-27_04.02.03_CuED_5_sum.fits
# [5/5] Deneb_2026-07-27_04.13.59_CuED_5_sum.fits
#                                            file  \
# 0        Alkaid_2026-07-27_04.00.51_CuED-0.fits
# 1    Altair_2026-07-27_04.11.14_CuED_5_sum.fits
# 2   Antares_2026-07-27_04.05.13_CuED_5_sum.fits
# 3  Arcturus_2026-07-27_04.02.03_CuED_5_sum.fits
# 4     Deneb_2026-07-27_04.13.59_CuED_5_sum.fits
#
#                                                 path            kind  \
# 0  /Users/svwbeckwith/Library/CloudStorage/Dropbo...  science_single
# 1  /Users/svwbeckwith/Library/CloudStorage/Dropbo...     science_sum
# 2  /Users/svwbeckwith/Library/CloudStorage/Dropbo...     science_sum
# 3  /Users/svwbeckwith/Library/CloudStorage/Dropbo...     science_sum
# 4  /Users/svwbeckwith/Library/CloudStorage/Dropbo...     science_sum
#
#       analysis_mode    object      camera  exposure_sec  nstars  \
# 0  source_detection    Alkaid  Apx60-CuED         0.010       2
# 1  source_detection    Altair  Apx60-CuED         0.015       2
# 2  source_detection   Antares  Apx60-CuED         0.020       5
# 3  source_detection  Arcturus  Apx60-CuED         0.005       8
# 4  source_detection     Deneb  Apx60-CuED         0.025      30
#
#    median_fwhm_pixels  median_background  background_sigma  brightest_flux  \
# 0            7.343746              108.0          5.866696         45431.0
# 1            3.950277              494.0         17.276219        240230.0
# 2            8.870814              503.0         20.413080        170222.0
# 3            1.682539              494.0         16.866729        184624.0
# 4            1.571725              494.0         11.645672        300033.0
#
#    peak_find_time_sec     stats_region focus_sharpness gradient_anisotropy  \
# 0            3.780289  center_fraction            None                None
# 1            3.730580  center_fraction            None                None
# 2            3.811934  center_fraction            None                None
# 3            3.754827  center_fraction            None                None
# 4            3.800769  center_fraction            None                None
#
#   gradient_angle_deg
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None

# %%
# Explicit analysis modes can be used when needed:
#   mode="source_detection"
#   mode="statistics"
#   mode="focus"
#   mode="rotation_blur"
#
# If mode is omitted, ImagingRun chooses a default from each file's kind.
# For example, darks and flats use statistics, while science images use source detection.
