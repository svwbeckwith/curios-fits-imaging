# %% [markdown]
# # FITS Imaging — Version 2.2 cleaned driver notebook
#
# This notebook keeps interactive work in Jupyter while moving reusable code into the `fits_imaging` package. The package functions are written so they can later be used by a command-line program or GUI.

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

from fits_imaging.config import ImagingConfig
from fits_imaging.fits_io import choose_file
from fits_imaging.analysis import analyze_fits_file
from fits_imaging.report import print_image_summary
from fits_imaging.plotting import (
    plot_image_with_peaks,
    plot_peak_cutouts,
    print_peak_table,
    plot_histogram,
    plot_convolved_image,
)

config = ImagingConfig()
config
# Out:
# ImagingConfig(telescope='90mm SVBony telescope', pixel_um=3.76, pixel_arcsec=1.55, xformat=9576, yformat=6380, maxcounts=65535, aperture_cm=9.0, focal_length_cm=50.0, zero_mag_counts=115000000.0, latitude_deg=37.78111, longitude_deg=-122.39139, data_root=PosixPath('/Users/svwbeckwith/Library/CloudStorage/Dropbox/CuRIOS/Software/Python/Data'))

# %% [markdown]
# ## Select a FITS file
#
# Set `data_root` to your top-level `DataDirectories` folder. `choose_file()` now handles either case: a folder containing FITS files directly, or a folder containing subdirectories of FITS files.

# %%
# Top-level CuRIOS data directory. Change this if you move the data.
data_root = Path('/Users/svwbeckwith/Dropbox/CuRIOS/Software/DataDirectories')

# This works whether data_root contains FITS files directly or contains run subdirectories.
image_path = choose_file(data_root, extensions=('.fits', '.fit'))
image_path
# Out:
# Directory#   Directory
# ----------------------------------------------------------------------
#     0       Archive
#     1       CowTests
#     2       Images
#     3       Lib-0610
#     4       Patio-0703
# ----------------------------------------------------------------------
# Choose directory number:  4
# File#       File
# ----------------------------------------------------------------------
#     0       VegaC0-Baht_2026-07-04_04.02.22_CuED-0.fits
#     1       VegaC0-Baht_2026-07-04_04.18.17_CuED-0.fits
#     2       VegaC0_2026-07-04_03.48.12_CuED-0.fits
#     3       VegaC0_2026-07-04_03.57.22_CuED-0.fits
#     4       VegaC0_2026-07-04_04.20.58_CuED-0.fits
#     5       VegaC0_2026-07-04_04.30.06_CuED-0.fits
#     6       VegaD1-Baht_2026-07-04_04.04.48_CuED-0.fits
#     7       VegaD1_2026-07-04_03.50.39_CuED-0.fits
#     8       VegaD1_2026-07-04_04.23.23_CuED-0.fits
#     9       VegaD2-Baht_2026-07-04_04.05.24_CuED-0.fits
#    10       VegaD2_2026-07-04_03.51.15_CuED-0.fits
#    11       VegaD2_2026-07-04_04.23.59_CuED-0.fits
#    12       VegaD3-Baht_2026-07-04_04.06.00_CuED-0.fits
#    13       VegaD3_2026-07-04_03.51.52_CuED-0.fits
#    14       VegaD3_2026-07-04_04.24.35_CuED-0.fits
#    15       VegaL1-Baht_2026-07-04_04.09.05_CuED-0.fits
#    16       VegaL1_2026-07-04_03.54.56_CuED-0.fits
#    17       VegaL1_2026-07-04_04.27.39_CuED-0.fits
#    18       VegaL2-Baht_2026-07-04_04.09.41_CuED-0.fits
#    19       VegaL2_2026-07-04_03.55.32_CuED-0.fits
#    20       VegaL2_2026-07-04_04.28.16_CuED-0.fits
#    21       VegaL3-Baht_2026-07-04_04.10.19_CuED-0.fits
#    22       VegaL3_2026-07-04_03.56.09_CuED-0.fits
#    23       VegaL3_2026-07-04_04.28.52_CuED-0.fits
#    24       VegaL4-Baht_2026-07-04_04.10.55_CuED-0.fits
#    25       VegaL4_2026-07-04_03.56.46_CuED-0.fits
#    26       VegaL4_2026-07-04_04.29.29_CuED-0.fits
#    27       VegaLL-Baht_2026-07-04_04.12.47_CuED-0.fits
#    28       VegaR1-Baht_2026-07-04_04.06.37_CuED-0.fits
#    29       VegaR1_2026-07-04_03.52.29_CuED-0.fits
#    30       VegaR1_2026-07-04_04.25.13_CuED-0.fits
#    31       VegaR2-Baht_2026-07-04_04.07.15_CuED-0.fits
#    32       VegaR2_2026-07-04_03.53.06_CuED-0.fits
#    33       VegaR2_2026-07-04_04.25.50_CuED-0.fits
#    34       VegaR3-Baht_2026-07-04_04.07.51_CuED-0.fits
#    35       VegaR3_2026-07-04_03.53.42_CuED-0.fits
#    36       VegaR3_2026-07-04_04.26.26_CuED-0.fits
#    37       VegaR4-Baht_2026-07-04_04.08.27_CuED-0.fits
#    38       VegaR4_2026-07-04_03.54.18_CuED-0.fits
#    39       VegaR4_2026-07-04_04.27.02_CuED-0.fits
#    40       VegaU1-Baht_2026-07-04_04.02.58_CuED-0.fits
#    41       VegaU1_2026-07-04_03.48.50_CuED-0.fits
#    42       VegaU1_2026-07-04_04.21.34_CuED-0.fits
#    43       VegaU2-Baht_2026-07-04_04.03.36_CuED-0.fits
#    44       VegaU2_2026-07-04_03.49.27_CuED-0.fits
#    45       VegaU2_2026-07-04_04.22.10_CuED-0.fits
#    46       VegaU3-Baht_2026-07-04_04.04.12_CuED-0.fits
#    47       VegaU3_2026-07-04_03.50.03_CuED-0.fits
#    48       VegaU3_2026-07-04_04.22.46_CuED-0.fits
#    49       VegaUL-Baht_2026-07-04_04.12.10_CuED-0.fits
#    50       VegaUR-Baht_2026-07-04_04.11.32_CuED-0.fits
#    51       Vega_2026-07-04_03.39.13_CuED-0.fits
#    52       Vega_2026-07-04_03.39.13_CuED_5_sum.fits
#    53       Vega_2026-07-04_03.42.39_CuED-0.fits
#    54       Vega_2026-07-04_03.42.39_CuED_5_sum.fits
# ----------------------------------------------------------------------
# Enter file number to analyze:  4
# PosixPath('/Users/svwbeckwith/Dropbox/CuRIOS/Software/DataDirectories/Patio-0703/VegaC0_2026-07-04_04.20.58_CuED-0.fits')

# %% [markdown]
# ## Read image and find peaks

# %%
record, imagec, peaksarray, stats = analyze_fits_file(
    image_path,
    peak_separation=10.0,
    peak_sharp=0.2,
    maxsources=400,
    fit_method='gaussian',   # use 'moments' for faster center-of-light estimates
)

print_image_summary(record, imagec, stats)
# Out:
# VegaC0  9576 x 6380  Apx60-CuED  0.001 sec
# RAH:  18.630  Dec:  38.810  PA: 286.40  PA2:  73.60  Alt:    47.9  Az:    71.1
# Mean: 99.1  Median: 99.0  Std: 4.6  Min: 0.0  Max: 3044.0
# Found 5 peaks in 2.71 sec

# %% [markdown]
# ## Full image with labeled peaks

# %%
title = f'{record.object_name}   {record.camera}  {record.exposure_sec:.3f} sec'
fig, ax = plot_image_with_peaks(imagec, peaksarray, title=title, figsize=(16, 16))
plt.show()

# %% [markdown]
# ## Peak table

# %%
swarpfac = -1.0 if record.softname == 'SWarp' else 1.0
print_peak_table(
    peaksarray,
    exposure_sec=record.exposure_sec,
    zero_mag_counts=config.zero_mag_counts,
    pa0=record.pa_deg,
    swarpfac=swarpfac,
    max_rows=200,
)
# Out:
# FOV PA: 286.40 deg
# Peak     x0       y0        Area    Mag        dr      PA(deg)       Flux
#    0  4659.55  3289.57      30782   1.43       0.00       0.00      37555
#    1  9012.30   877.52        153   7.19    4976.39     -61.01        154
#    2  8348.12  2527.91        187   6.97    3766.39     -78.33        148
#    3  8142.66  1361.49        181   7.01    3981.15     -61.03        140
#    4  7470.33  2743.41        147   7.23    2863.35     -79.00        126

# %% [markdown]
# ## Peak cutouts

# %%
if len(peaksarray) > 0:
    fig, axs = plot_peak_cutouts(
        imagec,
        peaksarray,
        nmax=25,
        spansize=24,
        pixel_arcsec=config.pixel_arcsec,
        exposure_sec=record.exposure_sec,
        zero_mag_counts=config.zero_mag_counts,
    )
    plt.show()
else:
    print('No peaks found.')

# %% [markdown]
# ## Optional diagnostic plots

# %%
fig, ax = plot_histogram(imagec, title=record.filename)
plt.show()

# %%
convolved_image, fig, ax = plot_convolved_image(imagec, title=f'{record.filename}: W5x5 convolution')
plt.show()
